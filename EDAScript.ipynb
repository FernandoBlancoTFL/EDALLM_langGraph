# %% [markdown]
# # 1. Configuración del entorno

# %%
import pandas as pd

# %%
# Mostramos todas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 2. Obtención de los datos

# %%
# Cargar dataset (ajusta la ruta al archivo que descargaste)
df = pd.read_excel("./Data/ncr_ride_bookings.xlsx")

# %%
# Creación del DataFrame
dataframe = pd.DataFrame(df)

# %%
# Mostramos las primeras filas del DataFrame
dataframe.head(5)
# Out:
#         Date      Time    Booking ID   Booking Status   Customer ID  \
# 0 2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1 2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2 2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3 2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4 2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location             Avg VTAT  \
# 0          eBike          Palam Vihar            Jhilmil                  NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56  2025-09-04 00:00:00
# 2           Auto              Khandsa      Malviya Nagar  2025-04-13 00:00:00
# 3  Premier Sedan  Central Secretariat           Inderlok  2025-01-13 00:00:00
# 4           Bike     Ghitorni Village        Khan Market  2025-03-05 00:00:00
#
#               Avg CTAT  Cancelled Rides by Customer  \
# ...

# %% [markdown]
# # 3. Exámen inicial de los datos

# %% [markdown]
# #### Entendimiento de la estructura básica de los datos

# %%
print("Información del DataFrame:")
dataframe.info()
# Out:
# Información del DataFrame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  datetime64[ns]
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  object
#  9   Avg CTAT                           102000 non-null  object
# ...

# %%
# Estadísticas descriptivas básicas
print("Estadísticas descriptivas:")
dataframe.describe()
# Out:
# Estadísticas descriptivas:
#                              Date  Cancelled Rides by Customer  \
# count                      150000                      10500.0
# mean   2024-06-30 16:42:40.320000                          1.0
# min           2024-01-01 00:00:00                          1.0
# 25%           2024-03-31 00:00:00                          1.0
# 50%           2024-07-01 00:00:00                          1.0
# 75%           2024-09-30 00:00:00                          1.0
# max           2024-12-30 00:00:00                          1.0
# std                           NaN                          0.0
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value
# count                    27000.0            9000.0  102000.000000
# mean                         1.0               1.0     508.295912
# min                          1.0               1.0      50.000000
# 25%                          1.0               1.0     234.000000
# ...

# %%
# Verificación de valores nulos
print("Valores nulos por columna:")
dataframe.isnull().sum()
# Out:
# Valores nulos por columna:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# ...

# %%
print(df.describe(include="all"))
# Out:
#                               Date      Time    Booking ID Booking Status  \
# count                       150000    150000        150000         150000
# unique                         NaN     62910        148767              5
# top                            NaN  17:44:57  "CNR3648267"      Completed
# freq                           NaN        16             3          93000
# mean    2024-06-30 16:42:40.320000       NaN           NaN            NaN
# min            2024-01-01 00:00:00       NaN           NaN            NaN
# 25%            2024-03-31 00:00:00       NaN           NaN            NaN
# 50%            2024-07-01 00:00:00       NaN           NaN            NaN
# 75%            2024-09-30 00:00:00       NaN           NaN            NaN
# max            2024-12-30 00:00:00       NaN           NaN            NaN
# std                            NaN       NaN           NaN            NaN
#
#          Customer ID Vehicle Type Pickup Location Drop Location  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histograma de una variable numérica
df["Date"].hist()
plt.show()

# %%
# Conteo de valores en variable categórica
sns.countplot(x="Reason for cancelling by Customer", data=df)
plt.show()

# %%
import sqlite3

# %%
from utils_db import save_to_db

# %%
save_to_db(df, db_name="ncr_bookings.db", table_name="bookings")
# Out:
# ✅ DataFrame saved to ncr_bookings.db, table: bookings

# %%
# Volver a abrir la conexión
conn = sqlite3.connect("ncr_bookings.db")

# Leer con SQL directamente
query = "SELECT * FROM bookings LIMIT 5;"
df_sql = pd.read_sql(query, conn)

print(df_sql)

conn.close()
# Out:
#                   Date             Time    Booking ID   Booking Status  \
# 0  2024-03-23 00:00:00  12:29:38.000000  "CNR5884300"  No Driver Found
# 1  2024-11-29 00:00:00  18:01:39.000000  "CNR1326809"       Incomplete
# 2  2024-08-23 00:00:00  08:56:10.000000  "CNR8494506"        Completed
# 3  2024-10-21 00:00:00  17:17:25.000000  "CNR8906825"        Completed
# 4  2024-09-16 00:00:00  22:08:00.000000  "CNR1950162"        Completed
#
#     Customer ID   Vehicle Type      Pickup Location      Drop Location  \
# 0  "CID1982111"          eBike          Palam Vihar            Jhilmil
# 1  "CID4604802"       Go Sedan        Shastri Nagar  Gurgaon Sector 56
# 2  "CID9202816"           Auto              Khandsa      Malviya Nagar
# 3  "CID2610914"  Premier Sedan  Central Secretariat           Inderlok
# 4  "CID9933542"           Bike     Ghitorni Village        Khan Market
#
#               Avg VTAT             Avg CTAT Cancelled Rides by Customer  \
# ...
